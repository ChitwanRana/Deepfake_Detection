# %%
import os
import kaggle

# Define the path where the dataset should be downloaded
download_path = "Z:\\Deepfake dataset"

# Make sure the download path exists
if not os.path.exists(download_path):
    os.makedirs(download_path)

# Download the dataset using Kaggle API
# Replace "manjilkarki/deepfake-and-real-images" with the correct dataset name/slug from Kaggle
# !kaggle datasets download -d manjilkarki/deepfake-and-real-images -p "{download_path}" --unzip

print("Dataset downloaded to:", download_path)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/manjilkarki/deepfake-and-real-imagesDataset downloaded to: Z:\Deepfake dataset
#
# License(s): unknown
# ...
#   0%|          | 0.00/1.68G [00:00<?, ?B/s]
#   0%|          | 1.00M/1.68G [00:01<44:57, 670kB/s]
#   0%|          | 2.00M/1.68G [00:01<22:24, 1.34MB/s]
#   0%|          | 3.00M/1.68G [00:02<17:43, 1.70MB/s]
#   0%|          | 5.00M/1.68G [00:02<09:39, 3.11MB/s]
#   0%|          | 7.00M/1.68G [00:02<06:12, 4.83MB/s]
#   1%|          | 9.00M/1.68G [00:02<04:36, 6.50MB/s]
#   1%|          | 11.0M/1.68G [00:02<03:44, 8.01MB/s]
#   1%|          | 13.0M/1.68G [00:03<03:09, 9.45MB/s]
#   1%|          | 15.0M/1.68G [00:03<02:49, 10.6MB/s]
#   1%|          | 17.0M/1.68G [00:03<02:33, 11.6MB/s]
#   1%|          | 19.0M/1.68G [00:03<02:24, 12.4MB/s]
#   1%|          | 21.0M/1.68G [00:03<02:18, 12.9MB/s]
#   1%|▏         | 23.0M/1.68G [00:03<02:15, 13.2MB/s]
#   1%|▏         | 25.0M/1.68G [00:03<02:12, 13.5MB/s]
# ...
